# %%
import torch 
import torchvision.transforms as transforms 
import torch.nn as nn 
import torch.nn.functional as F 
import numpy as np 
import matplotlib.pyplot as plt 

from torchvision.datasets import CIFAR10 
from torch.utils.data import DataLoader 
from torch.optim import Adam 
import torchvision 

torch.manual_seed(1)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ### Data

# %%
compute_transform = transforms.Compose(
    [ 
        transforms.ToTensor()
    ]
)

dataset = CIFAR10(
    root='./data', 
    train=True, 
    transform=compute_transform, 
    download=True
)

loader = DataLoader(
    dataset, 
    batch_size=1024, 
    shuffle=False, 
    num_workers=4
)

mean = 0.0 
for images, _ in loader:
    batch_samples = images.size(0)
    images = images.view(batch_samples, images.size(1), -1)
    mean += images.mean(2).sum(0)
mean = mean / len(loader.dataset)

variance = 0.0 
for images, _ in loader:
    batch_samples = images.size(0)
    images = images.view(batch_samples, images.size(1), -1)
    variance += ((images - mean.unsqueeze(1)) ** 2).sum([0,2])
std = torch.sqrt(variance / (len(loader.dataset)*32*32))

print(mean, std)
# Out:
# Files already downloaded and verified
# tensor([0.4914, 0.4822, 0.4465]) tensor([0.2470, 0.2435, 0.2616])

# %%
batch_size = 256 
transform = transforms.Compose( 
    [
        transforms.ToTensor(), 
        transforms.Normalize(mean, std)
    ]
)

train_set = CIFAR10(
    root='./data', 
    train=True, 
    download=True, 
    transform=transform
)

val_set = CIFAR10(
    root='./data', 
    train=False, 
    download=True,
    transform=transform
)

trainloader = DataLoader(
    train_set, 
    batch_size=batch_size, 
    shuffle=True, 
    num_workers=4
)

testloader = DataLoader(
    val_set, 
    batch_size=batch_size, 
    shuffle=False, 
    num_workers=4
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### Model

# %%
class CNNModel(nn.Module):
    def __init__(self, n_classes=10):
        super(CNNModel, self).__init__()
        self.conv_layer1 = nn.Sequential(
            nn.Conv2d(3, 64, 3, stride=1, padding='same'),
            nn.ReLU()
        )
        self.conv_layer2 = nn.Sequential(
            nn.Conv2d(64, 64, 3, stride=1, padding='same'),
            nn.ReLU()
        )
        self.conv_layer3 = nn.Sequential(
            nn.Conv2d(64, 64, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
        )
        
        self.conv_layer4 = nn.Sequential(
            nn.Conv2d(64, 128, 3, stride=1, padding='same'),
            nn.ReLU(),
        )
        self.conv_layer5 = nn.Sequential(
            nn.Conv2d(128, 128, 3, stride=1, padding='same'),
            nn.ReLU(),
        )
        self.conv_layer6 = nn.Sequential(
            nn.Conv2d(128, 128, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
        )

        self.conv_layer7 = nn.Sequential(
            nn.Conv2d(128, 256, 3, stride=1, padding='same'),
            nn.ReLU(),
        )
        self.conv_layer8 = nn.Sequential(
            nn.Conv2d(256, 256, 3, stride=1, padding='same'),
            nn.ReLU(),
        )
        self.conv_layer9 = nn.Sequential(
            nn.Conv2d(256, 256, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
        )

        self.conv_layer10 = nn.Sequential(
            nn.Conv2d(256, 512, 3, stride=1, padding='same'),
            nn.ReLU(),
        )
        self.conv_layer11 = nn.Sequential(
            nn.Conv2d(512, 512, 3, stride=1, padding='same'),
            nn.ReLU(),
        )
        self.conv_layer12 = nn.Sequential(
            nn.Conv2d(512, 512, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
        )

        self.flatten = nn.Flatten()

        self.fc_layer1 = nn.Sequential(
            nn.Linear(512 * 2 * 2, 512),
            nn.ReLU()
        )
        self.fc_layer2 = nn.Linear(512, n_classes)
    
    def forward(self, x):
        x = self.conv_layer1(x)
        x = self.conv_layer2(x)
        x = self.conv_layer3(x)
        x = self.conv_layer4(x)
        x = self.conv_layer5(x)
        x = self.conv_layer6(x)
        x = self.conv_layer7(x)
        x = self.conv_layer8(x)
        x = self.conv_layer9(x)
        x = self.conv_layer10(x)
        x = self.conv_layer11(x)
        x = self.conv_layer12(x)
        x = self.flatten(x)
        x = self.fc_layer1(x)
        out = self.fc_layer2(x)

        return out

# %%
model = CNNModel(10)
model.to(device)
print(model)
# Out:
# CNNModel(
#   (conv_layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#   )
#   (conv_layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#   )
#   (conv_layer3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_layer4): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#   )
#   (conv_layer5): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#   )
#   (conv_layer6): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_layer7): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#   )
#   (conv_layer8): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#   )
#   (conv_layer9): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_layer10): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#   )
#   (conv_layer11): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#   )
#   (conv_layer12): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc_layer1): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): ReLU()
#   )
#   (fc_layer2): Linear(in_features=512, out_features=10, bias=True)
# )

# %% [markdown]
# ### Train

# %%
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=1e-3)

# %%
def evaluate(model, testloader, criterion):
    model.eval()
    test_loss = 0.0 
    running_correct = 0 
    total = 0 
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            running_correct += (predicted == labels).sum().item() 

    accuracy = 100 * running_correct / total 
    test_loss = test_loss / len(testloader)
    return test_loss, accuracy

# %%
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
max_epoch = 50

# %%
for epoch in range(max_epoch):
    model.train()
    running_loss = 0.0 
    running_correct = 0
    total = 0 

    for i, (inputs, labels) in enumerate(trainloader, 0):
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()

        loss.backward()
        optimizer.step()

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        running_correct += (predicted == labels).sum().item()

    epoch_accuracy = 100 * running_correct / total 
    epoch_loss = running_correct / (i + 1)

    test_loss, test_accuracy = evaluate(model, testloader, criterion)
    print(f"Epoch [{epoch + 1}/{max_epoch}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")

    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
# Out:
# Epoch [1/50], Loss: 49.9439, Accuracy: 19.58%, Test Loss: 1.8618, Test Accuracy: 29.97%
# Epoch [2/50], Loss: 98.3265, Accuracy: 38.54%, Test Loss: 1.5304, Test Accuracy: 43.54%
# Epoch [3/50], Loss: 129.4490, Accuracy: 50.74%, Test Loss: 1.2376, Test Accuracy: 54.23%
# Epoch [4/50], Loss: 152.7602, Accuracy: 59.88%, Test Loss: 1.1407, Test Accuracy: 57.98%
# Epoch [5/50], Loss: 168.0510, Accuracy: 65.88%, Test Loss: 0.9183, Test Accuracy: 66.96%
# Epoch [6/50], Loss: 181.1071, Accuracy: 70.99%, Test Loss: 0.8344, Test Accuracy: 70.64%
# Epoch [7/50], Loss: 190.3214, Accuracy: 74.61%, Test Loss: 0.7886, Test Accuracy: 72.72%
# Epoch [8/50], Loss: 197.6378, Accuracy: 77.47%, Test Loss: 0.8219, Test Accuracy: 73.30%
# Epoch [9/50], Loss: 204.8214, Accuracy: 80.29%, Test Loss: 0.7744, Test Accuracy: 74.15%
# Epoch [10/50], Loss: 211.1939, Accuracy: 82.79%, Test Loss: 0.7664, Test Accuracy: 75.16%
# Epoch [11/50], Loss: 215.9847, Accuracy: 84.67%, Test Loss: 0.7819, Test Accuracy: 74.40%
# Epoch [12/50], Loss: 220.3010, Accuracy: 86.36%, Test Loss: 0.7473, Test Accuracy: 75.97%
# Epoch [13/50], Loss: 224.5714, Accuracy: 88.03%, Test Loss: 0.7794, Test Accuracy: 76.77%
# Epoch [14/50], Loss: 229.1633, Accuracy: 89.83%, Test Loss: 0.8148, Test Accuracy: 76.74%
# Epoch [15/50], Loss: 231.7398, Accuracy: 90.84%, Test Loss: 0.8139, Test Accuracy: 76.65%
# Epoch [16/50], Loss: 234.0000, Accuracy: 91.73%, Test Loss: 0.8732, Test Accuracy: 76.25%
# Epoch [17/50], Loss: 236.5357, Accuracy: 92.72%, Test Loss: 0.9274, Test Accuracy: 76.42%
# Epoch [18/50], Loss: 239.1122, Accuracy: 93.73%, Test Loss: 1.0021, Test Accuracy: 76.98%
# Epoch [19/50], Loss: 240.1173, Accuracy: 94.13%, Test Loss: 0.9541, Test Accuracy: 77.30%
# Epoch [20/50], Loss: 242.6582, Accuracy: 95.12%, Test Loss: 0.9621, Test Accuracy: 77.54%
# Epoch [21/50], Loss: 243.0612, Accuracy: 95.28%, Test Loss: 1.0588, Test Accuracy: 76.90%
# Epoch [22/50], Loss: 243.7449, Accuracy: 95.55%, Test Loss: 1.0065, Test Accuracy: 77.03%
# Epoch [23/50], Loss: 244.7704, Accuracy: 95.95%, Test Loss: 1.1232, Test Accuracy: 76.62%
# Epoch [24/50], Loss: 244.6633, Accuracy: 95.91%, Test Loss: 1.0310, Test Accuracy: 76.97%
# Epoch [25/50], Loss: 245.8418, Accuracy: 96.37%, Test Loss: 1.0773, Test Accuracy: 76.88%
# Epoch [26/50], Loss: 247.3112, Accuracy: 96.95%, Test Loss: 1.0847, Test Accuracy: 77.39%
# Epoch [27/50], Loss: 246.7449, Accuracy: 96.72%, Test Loss: 1.1467, Test Accuracy: 77.12%
# Epoch [28/50], Loss: 247.6633, Accuracy: 97.08%, Test Loss: 1.2964, Test Accuracy: 77.04%
# Epoch [29/50], Loss: 248.2755, Accuracy: 97.32%, Test Loss: 1.2979, Test Accuracy: 76.42%
# Epoch [30/50], Loss: 247.6429, Accuracy: 97.08%, Test Loss: 1.2462, Test Accuracy: 78.08%
# Epoch [31/50], Loss: 248.6786, Accuracy: 97.48%, Test Loss: 1.3119, Test Accuracy: 77.19%
# Epoch [32/50], Loss: 248.1224, Accuracy: 97.26%, Test Loss: 1.3010, Test Accuracy: 77.30%
# Epoch [33/50], Loss: 248.7551, Accuracy: 97.51%, Test Loss: 1.3027, Test Accuracy: 77.69%
# Epoch [34/50], Loss: 249.1684, Accuracy: 97.67%, Test Loss: 1.2575, Test Accuracy: 77.71%
# Epoch [35/50], Loss: 249.4592, Accuracy: 97.79%, Test Loss: 1.2022, Test Accuracy: 77.90%
# Epoch [36/50], Loss: 249.0510, Accuracy: 97.63%, Test Loss: 1.3164, Test Accuracy: 76.50%
# Epoch [37/50], Loss: 248.5204, Accuracy: 97.42%, Test Loss: 1.2066, Test Accuracy: 77.68%
# Epoch [38/50], Loss: 249.2041, Accuracy: 97.69%, Test Loss: 1.3827, Test Accuracy: 77.29%
# Epoch [39/50], Loss: 248.9235, Accuracy: 97.58%, Test Loss: 1.4399, Test Accuracy: 77.62%
# Epoch [40/50], Loss: 249.7704, Accuracy: 97.91%, Test Loss: 1.2889, Test Accuracy: 77.02%
# Epoch [41/50], Loss: 249.7755, Accuracy: 97.91%, Test Loss: 1.3457, Test Accuracy: 76.76%
# Epoch [42/50], Loss: 249.9643, Accuracy: 97.99%, Test Loss: 1.4012, Test Accuracy: 77.21%
# Epoch [43/50], Loss: 249.3214, Accuracy: 97.73%, Test Loss: 1.3018, Test Accuracy: 77.04%
# Epoch [44/50], Loss: 250.3010, Accuracy: 98.12%, Test Loss: 1.3163, Test Accuracy: 78.28%
# Epoch [45/50], Loss: 249.9694, Accuracy: 97.99%, Test Loss: 1.3380, Test Accuracy: 77.62%
# Epoch [46/50], Loss: 250.5510, Accuracy: 98.22%, Test Loss: 1.3342, Test Accuracy: 77.95%
# Epoch [47/50], Loss: 250.0255, Accuracy: 98.01%, Test Loss: 1.6933, Test Accuracy: 77.54%
# Epoch [48/50], Loss: 249.4745, Accuracy: 97.79%, Test Loss: 1.2216, Test Accuracy: 77.37%
# Epoch [49/50], Loss: 250.4439, Accuracy: 98.17%, Test Loss: 1.3590, Test Accuracy: 77.79%
# Epoch [50/50], Loss: 249.5918, Accuracy: 97.84%, Test Loss: 1.3893, Test Accuracy: 77.45%

# %%
import matplotlib.pyplot as plt 

plt.plot(train_accuracies, label='train_accuracy')
plt.plot(test_accuracies, label='test_accuracy')
plt.legend()
